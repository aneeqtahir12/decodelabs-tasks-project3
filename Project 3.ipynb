# %% [markdown]
# ## Task 1

# %%
import pandas as pd

# %%
dataset = pd.read_csv("Social_Network_Ads.csv")
dataset.head(10)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0
# 5   27            58000          0
# 6   27            84000          0
# 7   32           150000          1
# 8   25            33000          0
# 9   35            65000          0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              400 non-null    int64
#  1   EstimatedSalary  400 non-null    int64
#  2   Purchased        400 non-null    int64
# dtypes: int64(3)
# memory usage: 9.5 KB

# %%
dataset.shape
# Out:
# (400, 3)

# %%
dataset.size
# Out:
# 1200

# %%
dataset.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %% [markdown]
# ## Task 2

# %%
dataset.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
dataset.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# Length: 400, dtype: bool

# %%
dataset.duplicated().sum()
# Out:
# np.int64(33)

# %%
dataset = dataset.drop_duplicates()

# %%
dataset.shape
# Out:
# (367, 3)

# %% [markdown]
# ## Task 3

# %%
dataset['Purchased'].value_counts(normalize=True)
# Out:
# Purchased
# 0    0.623978
# 1    0.376022
# Name: proportion, dtype: float64

# %%
dataset.groupby('Purchased')[['Age', 'EstimatedSalary']].mean()
# Out:
#                  Age  EstimatedSalary
# Purchased
# 0          32.537118     60593.886463
# 1          46.326087     87521.739130

# %% [markdown]
# ## Task 4

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(data=dataset, x='Age', y='EstimatedSalary', hue='Purchased', palette='Set1', alpha=0.8)
plt.title('Age vs Estimated Salary by Purchase Status')
plt.xlabel('Age (Years)')
plt.ylabel('Estimated Salary ($)')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(data=dataset, x='Purchased', palette='Set2')
plt.title('Distribution of Purchases (Target Variable)')
plt.xlabel('Purchased (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13116\2516366341.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=dataset, x='Purchased', palette='Set2')

# %% [markdown]
# ## Task 5

# %%
from sklearn.model_selection import train_test_split

# %%
x = dataset.iloc[:,:-1]
y = dataset['Purchased']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
x_train_scaled = sc.fit_transform(x_train)
x_test_scaled = sc.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
y_pred = lr.predict(x_test_scaled)

# %%
print(f"Accuracy Score: {accuracy_score(y_test, y_pred)}")
# Out:
# Accuracy Score: 0.8695652173913043

# %%
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[51  5]
#  [ 7 29]]

# %%
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89        56
#            1       0.85      0.81      0.83        36
#
#     accuracy                           0.87        92
#    macro avg       0.87      0.86      0.86        92
# weighted avg       0.87      0.87      0.87        92

# %% [markdown]
# ### Check on data

# %%
lr.predict(sc.transform([[32,150000	]]))
# Out:
# C:\Users\user\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([1])
